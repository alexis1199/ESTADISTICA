# %% [markdown]
# <a href="https://colab.research.google.com/github/alexis1199/ESTADISTICA/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/alexis1199/ESTADISTICA/refs/heads/main/Hipertension_Arterial_Mexico.csv')
df.dropna(inplace=True)
df
# Out:
#             FOLIO_I  sexo  edad  concentracion_hemoglobina  \
# 0     2022_01001004     2    41                       14.2
# 1     2022_01001009     2    65                       14.1
# 2     2022_01001012     2    68                       14.2
# 3     2022_01001013     1    35                       15.7
# 4     2022_01001015     2    65                       12.7
# ...             ...   ...   ...                        ...
# 4358  2022_32056019     2    62                       14.2
# 4359  2022_32056024     1    39                       14.2
# 4360  2022_32056026     2    69                       15.9
# 4361  2022_32056029     1    67                       17.6
# 4362  2022_32056030     2    56                       14.2
#
#       temperatura_ambiente  valor_acido_urico  valor_albumina  \
# 0                       22                4.8             4.0
# 1                        9                4.4             3.8
# 2                       22                4.8             4.0
# ...

# %%
df.drop(columns=['FOLIO_I'], inplace=True)
df
# Out:
#       sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0        2    41                       14.2                    22
# 1        2    65                       14.1                     9
# 2        2    68                       14.2                    22
# 3        1    35                       15.7                    11
# 4        2    65                       12.7                     7
# ...    ...   ...                        ...                   ...
# 4358     2    62                       14.2                    22
# 4359     1    39                       14.2                    22
# 4360     2    69                       15.9                    11
# 4361     1    67                       17.6                    14
# 4362     2    56                       14.2                    22
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                   4.8             4.0                    34
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['sexo'], kde = True, color = 'skyblue')

plt.xlabel('Sexo')
plt.ylabel('Frecuencia')
plt.title('Distribución de Sexo')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['edad'], kde = True, color = 'skyblue')

plt.xlabel('edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de edad')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['concentracion_hemoglobina'], kde = True, color = 'skyblue')

plt.xlabel('Hemoglobina')
plt.ylabel('Frecuencia')
plt.title('Distribución de Hemoglobina')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['temperatura_ambiente'], kde = True, color = 'skyblue')

plt.xlabel('Temperatura ambiente')
plt.ylabel('Frecuencia')
plt.title('Distribución de Temperatura ambiente')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['valor_acido_urico'], kde = True, color = 'skyblue')

plt.xlabel('Acido Urico')
plt.ylabel('Frecuencia')
plt.title('Distribución de Acido Urico')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['valor_albumina'], kde = True, color = 'skyblue')

plt.xlabel('Albumina')
plt.ylabel('Frecuencia')
plt.title('Distribución de Albumina')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['valor_colesterol_hdl'], kde = True, color = 'skyblue')

plt.xlabel('Colesterol hdl')
plt.ylabel('Frecuencia')
plt.title('Distribución de Colesterol hdl')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['valor_colesterol_ldl'], kde = True, color = 'skyblue')

plt.xlabel('Colesterol ldl')
plt.ylabel('Frecuencia')
plt.title('Distribución de Colesterol ldl')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['valor_colesterol_total'], kde = True, color = 'skyblue')

plt.xlabel('Colesterol total')
plt.ylabel('Frecuencia')
plt.title('Distribución de Colesterol total')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['valor_creatina'], kde = True, color = 'skyblue')

plt.xlabel('Creatina')
plt.ylabel('Frecuencia')
plt.title('Distribución de Creatina')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['segundamedicion_peso'], kde = True, color = 'skyblue')

plt.xlabel('segundamedicion peso')
plt.ylabel('Frecuencia')
plt.title('Distribución de segundamedicion peso')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['segundamedicion_estatura'], kde = True, color = 'skyblue')

plt.xlabel('segundamedicion estatura')
plt.ylabel('Frecuencia')
plt.title('Distribución de segundamedicion estatura')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['distancia_rodilla_talon'], kde = True, color = 'skyblue')

plt.xlabel('distancia rodilla talon')
plt.ylabel('Frecuencia')
plt.title('Distribución de distancia rodilla talon')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['circunferencia_de_la_pantorrilla'], kde = True, color = 'skyblue')

plt.xlabel('circunferencia de la pantorrilla')
plt.ylabel('Frecuencia')
plt.title('Distribución de circunferencia de la pantorrilla')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['segundamedicion_cintura'], kde = True, color = 'skyblue')

plt.xlabel('segundamedicion cintura')
plt.ylabel('Frecuencia')
plt.title('Distribución de segundamedicion cintura')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['tension_arterial'], kde = True, color = 'skyblue')

plt.xlabel('tension arterial')
plt.ylabel('Frecuencia')
plt.title('Distribución de tension arterial')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['sueno_horas'], kde = True, color = 'skyblue')

plt.xlabel('sueno horas')
plt.ylabel('Frecuencia')
plt.title('Distribución de sueno horas')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['masa_corporal'], kde = True, color = 'skyblue')

plt.xlabel('masa corporal')
plt.ylabel('Frecuencia')
plt.title('Distribución de masa corporal')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['actividad_total'], kde = True, color = 'skyblue')

plt.xlabel('actividad total')
plt.ylabel('Frecuencia')
plt.title('Distribución de actividad total')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['riesgo_hipertension'], kde = True, color = 'skyblue')

plt.xlabel('riesgo hipertension')
plt.ylabel('Frecuencia')
plt.title('Distribución de riesgo hipertension')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
matriz_de_correlacion = df.corr()
plt.figure(figsize = (20, 15))
sns.heatmap(matriz_de_correlacion, annot = True, cmap = 'coolwarm', fmt = "0.2f", square = True, cbar_kws = {'shrink': 0.8})
plt.title('Matriz de correlacion')
# Out:
# Text(0.5, 1.0, 'Matriz de correlacion')

# %% [markdown]
# ##'Hipótesis'
#
# El riesgo de tener hipertensión arterial está afectado por el nivel de glucosa en sangre y la edad."
#
# Variable dependiente: riesgo_hipertension
#
# Variables independientes: glucose, masa_corporal, edad

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm
import matplotlib.pyplot as plt

X = df[['masa_corporal', 'medida_cintura', 'peso', 'edad']]
Y = df['riesgo_hipertension']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()


Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test, Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de determinacion: {r2: 0.4f}')
# Out:
# Coeficiente de determinacion:  0.3696

# %%
b0, b1, b2, b3, b4= modelo.params

Fun = lambda X1, X2, X3, X4 : b0 + b1 * X1 + b2 * X2 + b3 * X3 +b4 +X4

Fun(0, 2.5, 4, 1)
# Out:
# 0.7641492740163076

# %%
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(modelo.resid, X_train_constante)
print(f'Valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}')
# Out:
# Valor-p de Breusch-Pagan:  0.0000

# %%
from statsmodels.formula.api import ols

moedo_2 = ols(formula = 'peso ~ edad + masa_corporal +  medida_cintura + concentracion_hemoglobina', data = df).fit()
tabla_anova = sm.stats.anova_lm(moedo_2, typ = 2)
tabla_anova
# Out:
#                                   sum_sq      df            F         PR(>F)
# edad                        19876.879510     1.0   204.511948   2.268475e-45
# masa_corporal              723909.057968     1.0  7448.254220   0.000000e+00
# medida_cintura              53256.806437     1.0   547.955892  3.002806e-114
# concentracion_hemoglobina    5017.485325     1.0    51.624587   7.865907e-13
# Residual                   423561.761094  4358.0          NaN            NaN
